# %%
import pandas as pd

# %%
df = pd.read_csv("Telco-Customer-Churn-100.csv")

# %%
df
# Out:
#      Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0           185  1024-GUALD  Female              0     Yes         No       1
# 1          2715  0484-JPBRU    Male              0      No         No      41
# 2          3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 3          1807  6910-HADCM  Female              0      No         No       1
# 4           132  8587-XYZSF    Male              0      No         No      67
# ..          ...         ...     ...            ...     ...        ...     ...
# 195        1452  0222-CNVPT    Male              1      No         No      52
# 196        3615  6900-PXRMS    Male              1     Yes        Yes      26
# 197         217  0230-WEQUW    Male              0     Yes         No      66
# 198        4235  7629-WFGLW  Female              1     Yes         No      56
# 199        4086  2235-EZAIK  Female              0     Yes         No      72
#
# ...

# %%
df['TotalCharges'].mean()
# Out:
# np.float64(2346.62575)

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')
